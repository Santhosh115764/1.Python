# %%
def subfields():
    print("sub-fields in AI are:")
    lists=[ 'Machine learning', 'Neural networks', 'Vision', 'Robotics', 'Speech processing', 'Natural language processing' ]
    for process in lists:
        print(process)

# %%
subfields()
# Out:
# sub-fields in AI are:
# Machine learning
# Neural networks
# Vision
# Robotics
# Speech processing
# Natural language processing

# %%
num=int(input("enter the number:"))
# Out:
# enter the number: 52452

# %%
def oddeven():
    if((num%2)==0):
        print("even number")
    else:
        print("odd number")

# %%
oddeven()
# Out:
# even number

# %%
def oddeven():
    if((num%2)==0):
        print("even number")
        message="give the even number"
    else:
        print("odd number")
        message="give the odd number"
    return message

# %%
oddeven()
# Out:
# even number
# 'give the even number'

# %%
message=oddeven()
# Out:
# even number

# %%
def marriage():
    gender=input("enter the gender:")
    age=int(input("enter the age:"))
    if(age>=21):
        print("eligible")
    else:
        print("not eligible")

# %%
marriage()
# Out:
# enter the gender: male
# enter the age: 21
# eligible

# %%
def marriage():
    gender=input("enter the gender:")
    age=int(input("enter the age:"))
    if(gender=="male"):
        if(age>=21):
            print("eligible")
        else:
            print("not eligible")
    elif(gender=="female"):
        if(age>=18):
            print("eligible")
        else:
            print("not eligible")
    else:
            print("Problem")

# %%
marriage()
# Out:
# enter the gender: male
# enter the age: 21
# eligible

# %%
def percentage():
    sub1=int(input("subject1="))
    sub2=int(input("subject1="))
    sub3=int(input("subject1="))
    sub4=int(input("subject1="))
    sub5=int(input("subject1="))
    total= sub1+sub2+sub3+sub4+sub5
    print("total:", sub1+sub2+sub3+sub4+sub5)
    percent=(total/500)*100
    print("percentage:", percent)

# %%
percentage()
# Out:
# subject1= 98
# subject1= 87
# subject1= 95
# subject1= 95
# subject1= 93
# total: 468
# percentage: 93.60000000000001

# %%
def triangle():
    height=int(input("height:"))
    breadth=int(input("breadth:"))
    print("area formula: (height*breadth)/2")
    print("area of triangle:",(height*breadth)/2)
    Height1=int(input("Height1:"))
    Height2=int(input("Height2:"))
    Breadth=int(input("Breadth:"))
    print("perimeter formula: Height1+Heigth2+Breadth")
    print("perimeter of triangle:",Height1+Height2+Breadth)

# %%
triangle()
# Out:
# height: 32
# breadth: 34
# area formula: (height*breadth)/2
# area of triangle: 544.0
# Height1: 2
# Height2: 4
# Breadth: 4
# perimeter formula: Height1+Heigth2+Breadth
# perimeter of triangle: 10
