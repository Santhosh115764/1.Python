# %%
age=int(input("enter the age:"))
# Out:
# enter the age: 18

# %%
if(age==18):
    print("adult")
# Out:
# adult

# %%
#if-else

# %%
age=int(input("enter the age:"))
# Out:
# enter the age: 18

# %%
if(age<=18):
    print("children")
else:
    print("adult")
# Out:
# children

# %%
age=int(input("enter the age:"))
# Out:
# enter the age: 18

# %%
if(age<18):
    print("children")
else:
    print("adult")
# Out:
# adult

# %%
#if elif

# %%
if():
    print()
elif():
    print()
elif():
    print()
else:
    print()

# %% [markdown]
# age<18-->children
# age<35-->adult
# age<59-->citizen
# age>59-->senior citizen

# %%
age=int(input("enter the age:"))
# Out:
# enter the age: 59

# %%
if(age<18):
    print("children")
elif(age<35):
    print("adult")
elif(age<59):
    print("citizen")
else:
    print("senior citizen")
# Out:
# senior citizen
