# %%
#for loop

# %%
lists=[2,19,36,59,78]

# %%
for temp in lists:
    print(temp)
# Out:
# 2
# 19
# 36
# 59
# 78

# %%
for age in lists:
    if(age<18):
        print("children")
    elif(age<35):
        print("adult")
    elif(age<59):
        print("citizen")
    else:
        print("senior citizen")
# Out:
# children
# adult
# citizen
# senior citizen
# senior citizen

# %%
num=int(input("enter the name:"))
if((num%2)==0):
    print("even number")
else:
    print("odd number")
# Out:
# enter the name: 3
# odd number

# %%
num=int(input("enter the number"))
if((num%2)==1):
    print("odd number")
else:
    print("even number")
# Out:
# enter the number 3
# odd number
