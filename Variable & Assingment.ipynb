# %%
print(10)
# Out:
# 10

# %%
print("WELCOME TO AI")
# Out:
# WELCOME TO AI

# %%
num1=20
num2=45
add=num1+num2
print(add)
# Out:
# 65

# %%
print("the addition of two numbers")
print("the number1:",num1)
print("the number2:",num2)
print("the addition:",num1+num2)
# Out:
# the addition of two numbers
# the number1: 20
# the number2: 45
# the addition: 65

# %%
sum1=83
sum2=43

# %%
print("the subraction of two numbers")
print("the sum1:",sum1)
print("the sum2:",sum2)
print("the sub:",sum1-sum2)
# Out:
# the subraction of two numbers
# the sum1: 83
# the sum2: 43
# the sub: 40
