# %%
print("Welcome to Assignment-1")
# Out:
# Welcome to Assignment-1

# %%
Num1=10
Num2=30
Add=(Num1+Num2)
print(Add)
# Out:
# 40

# %%
#Body Mass Index

# %% [markdown]
# Bmi<18-->underweight
# Bmi<25-->normalweight
# Bmi<34-->very overweight
# Bmi>45-->over overweight

# %%
Bmi=int(input("enter the weight:"))
# Out:
# enter the weight: 34

# %%
if(Bmi<18):
    print("underweight")
elif(Bmi<25):
    print("overweight")
elif(Bmi<=34):
    print("very overweight")
else:
    print("over overweight")
# Out:
# very overweight
