# %%
print("WELCOME TO AI")
# Out:
# WELCOME TO AI

# %%
first_name=input("enter the name")
# Out:
# enter the name Santhosh

# %%
last_name=input("enter the name")
# Out:
# enter the name N

# %%
num1=1000
num2=877
add=num1+num2

# %%
num1=int(input("enter the number1:"))
num2=int(input("enter the number2:"))
print(add)
# Out:
# enter the number1: 1000
# enter the number2: 877
# 1877
